# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 3
T_horizon     = 20

class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []
        
        self.fc1   = nn.Linear(4,256)
        self.fc_pi = nn.Linear(256,2)
        self.fc_v  = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
      
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition
            
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
            
        s,a,r,s_prime,done_mask, prob_a = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                          torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
                                          torch.tensor(done_lst, dtype=torch.float), torch.tensor(prob_a_lst)
        self.data = []
        return s, a, r, s_prime, done_mask, prob_a
        
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()

        for i in range(K_epoch):
            td_target = r + gamma * self.v(s_prime) * done_mask
            delta = td_target - self.v(s)
            delta = delta.detach().numpy()

            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]:
                advantage = gamma * lmbda * advantage + delta_t[0]
                advantage_lst.append([advantage])
            advantage_lst.reverse()
            advantage = torch.tensor(advantage_lst, dtype=torch.float)

            pi = self.pi(s, softmax_dim=1)
            pi_a = pi.gather(1,a)
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))  # a/b == exp(log(a)-log(b))

            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s) , td_target.detach())

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

# %%
env = gym.make('CartPole-v1')
model = PPO()
score = 0.0
print_interval = 20

for n_epi in range(10000):
    s, _ = env.reset()
    done = False
    while not done:
        for t in range(T_horizon):
            prob = model.pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample().item()
            s_prime, r, done, truncated, info = env.step(a)

            model.put_data((s, a, r/100.0, s_prime, prob[a].item(), done))
            s = s_prime

            score += r
            if done:
                break

        model.train_net()

    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
        score = 0.0

env.close()
# Out:
# C:\Users\User\anaconda3\envs\pytorch\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# C:\Users\User\AppData\Local\Temp\ipykernel_38772\432527925.py:53: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:248.)
#   s,a,r,s_prime,done_mask, prob_a = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
# # of episode :20, avg score : 26.1
# # of episode :40, avg score : 36.3
# # of episode :60, avg score : 68.3
# # of episode :80, avg score : 107.2
# # of episode :100, avg score : 56.3
# # of episode :120, avg score : 156.6
# # of episode :140, avg score : 311.4
# # of episode :160, avg score : 130.4
# # of episode :180, avg score : 196.2
# # of episode :200, avg score : 203.8
# # of episode :220, avg score : 36.0
# # of episode :240, avg score : 62.0
# # of episode :260, avg score : 132.6
# # of episode :280, avg score : 239.6
# # of episode :300, avg score : 167.5
# # of episode :320, avg score : 194.3
# # of episode :340, avg score : 111.8
# # of episode :360, avg score : 116.0
# # of episode :380, avg score : 120.2
# # of episode :400, avg score : 181.6
# # of episode :420, avg score : 185.8
# # of episode :440, avg score : 209.7
# # of episode :460, avg score : 296.8
# # of episode :480, avg score : 282.8
# # of episode :500, avg score : 291.2
# # of episode :520, avg score : 546.8
# # of episode :540, avg score : 483.2
# # of episode :560, avg score : 431.6
# # of episode :580, avg score : 542.1
# # of episode :600, avg score : 615.7
# # of episode :620, avg score : 290.5
# # of episode :640, avg score : 398.2
# # of episode :660, avg score : 1720.7
# # of episode :680, avg score : 2955.2
# # of episode :700, avg score : 162.7
# # of episode :720, avg score : 323.9
# # of episode :740, avg score : 1796.5
# # of episode :760, avg score : 149.3
# # of episode :780, avg score : 140.1
# # of episode :800, avg score : 138.2
# # of episode :820, avg score : 151.6
# # of episode :840, avg score : 144.7
# # of episode :860, avg score : 124.1
# # of episode :880, avg score : 121.5
# # of episode :900, avg score : 116.7
# # of episode :920, avg score : 135.9
# # of episode :940, avg score : 181.6
# # of episode :960, avg score : 293.8
# # of episode :980, avg score : 415.9
# # of episode :1000, avg score : 406.6
# # of episode :1020, avg score : 317.9
# # of episode :1040, avg score : 267.1
# # of episode :1060, avg score : 126.0
# # of episode :1080, avg score : 117.8
# # of episode :1100, avg score : 113.0
# # of episode :1120, avg score : 101.2
# # of episode :1140, avg score : 115.8
# # of episode :1160, avg score : 119.5
# # of episode :1180, avg score : 116.8
# # of episode :1200, avg score : 136.4
# # of episode :1220, avg score : 144.8
# # of episode :1240, avg score : 162.3
# # of episode :1260, avg score : 259.9
# # of episode :1280, avg score : 224.9
# # of episode :1300, avg score : 176.8
# # of episode :1320, avg score : 205.3
# # of episode :1340, avg score : 261.9
# # of episode :1360, avg score : 281.1
# # of episode :1380, avg score : 311.1
# # of episode :1400, avg score : 297.9
# # of episode :1420, avg score : 357.9
# # of episode :1440, avg score : 208.8
# # of episode :1460, avg score : 168.2
# # of episode :1480, avg score : 191.1
# # of episode :1500, avg score : 268.9
# # of episode :1520, avg score : 274.6
# # of episode :1540, avg score : 272.0
# # of episode :1560, avg score : 234.8
# # of episode :1580, avg score : 291.6
# # of episode :1600, avg score : 316.1
# # of episode :1620, avg score : 248.4
# # of episode :1640, avg score : 318.5
# # of episode :1660, avg score : 442.9
# # of episode :1680, avg score : 421.1
# # of episode :1700, avg score : 364.9
# # of episode :1720, avg score : 386.0
# # of episode :1740, avg score : 195.9
# # of episode :1760, avg score : 151.3
# # of episode :1780, avg score : 266.1
# # of episode :1800, avg score : 277.2
# # of episode :1820, avg score : 332.2
# # of episode :1840, avg score : 463.6
# # of episode :1860, avg score : 599.4
# # of episode :1880, avg score : 350.6
# # of episode :1900, avg score : 143.7
# # of episode :1920, avg score : 127.8
# # of episode :1940, avg score : 121.5
# # of episode :1960, avg score : 114.0
# # of episode :1980, avg score : 107.5
# # of episode :2000, avg score : 109.8
# # of episode :2020, avg score : 118.6
# # of episode :2040, avg score : 117.7
# # of episode :2060, avg score : 113.6
# # of episode :2080, avg score : 112.8
# # of episode :2100, avg score : 116.3
# # of episode :2120, avg score : 118.1
# # of episode :2140, avg score : 121.3
# # of episode :2160, avg score : 107.4
# # of episode :2180, avg score : 135.4
# # of episode :2200, avg score : 201.5
# # of episode :2220, avg score : 202.8
# # of episode :2240, avg score : 151.2
# # of episode :2260, avg score : 126.8
# # of episode :2280, avg score : 120.5
# # of episode :2300, avg score : 137.1
# # of episode :2320, avg score : 164.3
# # of episode :2340, avg score : 275.1
# # of episode :2360, avg score : 233.8
# # of episode :2380, avg score : 254.1
# # of episode :2400, avg score : 165.7
# # of episode :2420, avg score : 259.8
# # of episode :2440, avg score : 325.2
# # of episode :2460, avg score : 465.5
# # of episode :2480, avg score : 512.5
# # of episode :2500, avg score : 2179.1
# # of episode :2520, avg score : 40.1
# # of episode :2540, avg score : 65.1
# # of episode :2560, avg score : 145.3
# # of episode :2580, avg score : 330.3
# # of episode :2600, avg score : 262.8
# # of episode :2620, avg score : 211.8
# # of episode :2640, avg score : 171.3
# # of episode :2660, avg score : 240.3
# # of episode :2680, avg score : 467.6
# # of episode :2700, avg score : 228.2
# # of episode :2720, avg score : 144.2
# # of episode :2740, avg score : 139.8
# # of episode :2760, avg score : 136.8
# # of episode :2780, avg score : 140.7
# # of episode :2800, avg score : 161.1
# # of episode :2820, avg score : 204.2
# # of episode :2840, avg score : 385.4
# # of episode :2860, avg score : 316.5
# # of episode :2880, avg score : 246.1
# # of episode :2900, avg score : 352.6
# # of episode :2920, avg score : 374.1
# # of episode :2940, avg score : 388.6
# # of episode :2960, avg score : 317.6
# # of episode :2980, avg score : 298.0
# # of episode :3000, avg score : 363.3
# # of episode :3020, avg score : 314.5
# # of episode :3040, avg score : 146.6
# # of episode :3060, avg score : 116.6
# # of episode :3080, avg score : 117.5
# # of episode :3100, avg score : 127.4
# # of episode :3120, avg score : 132.3
# # of episode :3140, avg score : 146.8
# # of episode :3160, avg score : 144.1
# # of episode :3180, avg score : 142.1
# # of episode :3200, avg score : 139.7
# # of episode :3220, avg score : 141.7
# # of episode :3240, avg score : 137.5
# # of episode :3260, avg score : 173.4
# # of episode :3280, avg score : 233.7
# # of episode :3300, avg score : 338.8
# # of episode :3320, avg score : 373.5
# # of episode :3340, avg score : 255.5
# # of episode :3360, avg score : 220.3
# # of episode :3380, avg score : 227.8
# # of episode :3400, avg score : 308.9
# # of episode :3420, avg score : 341.6
# # of episode :3440, avg score : 339.5
# # of episode :3460, avg score : 318.6
# # of episode :3480, avg score : 327.8
# # of episode :3500, avg score : 302.6
# # of episode :3520, avg score : 289.8
# # of episode :3540, avg score : 501.3
# # of episode :3560, avg score : 673.8
# # of episode :3580, avg score : 348.6
# # of episode :3600, avg score : 3264.6
# # of episode :3620, avg score : 245.4
# # of episode :3640, avg score : 721.3
# # of episode :3660, avg score : 294.9
# # of episode :3680, avg score : 464.1
# # of episode :3700, avg score : 227.6
# # of episode :3720, avg score : 285.4
# # of episode :3740, avg score : 225.6
# # of episode :3760, avg score : 180.8
# # of episode :3780, avg score : 141.7
# # of episode :3800, avg score : 166.8
# # of episode :3820, avg score : 173.2
# # of episode :3840, avg score : 550.8
# # of episode :3860, avg score : 638.4
# # of episode :3880, avg score : 105.4
# # of episode :3900, avg score : 107.9
# # of episode :3920, avg score : 110.2
# # of episode :3940, avg score : 112.2
# # of episode :3960, avg score : 110.9
# # of episode :3980, avg score : 115.4
# # of episode :4000, avg score : 132.1
# # of episode :4020, avg score : 133.4
# # of episode :4040, avg score : 120.2
# # of episode :4060, avg score : 102.2
# # of episode :4080, avg score : 119.5
# # of episode :4100, avg score : 138.6
# # of episode :4120, avg score : 175.7
# # of episode :4140, avg score : 206.0
# # of episode :4160, avg score : 367.3
# # of episode :4180, avg score : 257.3
# # of episode :4200, avg score : 397.4
# # of episode :4220, avg score : 361.4
# # of episode :4240, avg score : 345.1
# # of episode :4260, avg score : 212.3
# # of episode :4280, avg score : 156.3
# # of episode :4300, avg score : 100.5
# # of episode :4320, avg score : 104.5
# # of episode :4340, avg score : 109.5
# # of episode :4360, avg score : 220.1
# # of episode :4380, avg score : 131.8
# # of episode :4400, avg score : 147.7
# # of episode :4420, avg score : 214.8
# # of episode :4440, avg score : 226.7
# # of episode :4460, avg score : 224.4
# # of episode :4480, avg score : 689.6
# # of episode :4500, avg score : 206.8
# # of episode :4520, avg score : 148.4
# # of episode :4540, avg score : 153.2
# # of episode :4560, avg score : 199.0
# # of episode :4580, avg score : 543.1
# # of episode :4600, avg score : 2144.5
# # of episode :4620, avg score : 761.9
# # of episode :4640, avg score : 437.9
# # of episode :4660, avg score : 241.2
# # of episode :4680, avg score : 267.9
# # of episode :4700, avg score : 321.6
# # of episode :4720, avg score : 460.1
# # of episode :4740, avg score : 341.1
# # of episode :4760, avg score : 591.8
# # of episode :4780, avg score : 259.4
# # of episode :4800, avg score : 354.2
# # of episode :4820, avg score : 390.1
# # of episode :4840, avg score : 197.8
# # of episode :4860, avg score : 202.1
# # of episode :4880, avg score : 187.7
# # of episode :4900, avg score : 145.2
# # of episode :4920, avg score : 134.3
# # of episode :4940, avg score : 127.5
# # of episode :4960, avg score : 104.5
# # of episode :4980, avg score : 91.6
# # of episode :5000, avg score : 97.5
# # of episode :5020, avg score : 85.3
# # of episode :5040, avg score : 100.5
# # of episode :5060, avg score : 133.7
# # of episode :5080, avg score : 138.6
# # of episode :5100, avg score : 142.3
# # of episode :5120, avg score : 148.0
# # of episode :5140, avg score : 152.9
# # of episode :5160, avg score : 145.1
# # of episode :5180, avg score : 153.1
# # of episode :5200, avg score : 144.8
# # of episode :5220, avg score : 129.7
# # of episode :5240, avg score : 112.7
# # of episode :5260, avg score : 105.9
# # of episode :5280, avg score : 104.0
# # of episode :5300, avg score : 105.8
# # of episode :5320, avg score : 139.3
# # of episode :5340, avg score : 209.8
# # of episode :5360, avg score : 195.8
# # of episode :5380, avg score : 159.8
# # of episode :5400, avg score : 150.1
# # of episode :5420, avg score : 140.2
# # of episode :5440, avg score : 152.7
# # of episode :5460, avg score : 159.3
# # of episode :5480, avg score : 194.4
# # of episode :5500, avg score : 400.9
# # of episode :5520, avg score : 447.4
# # of episode :5540, avg score : 278.4
# # of episode :5560, avg score : 256.1
# # of episode :5580, avg score : 491.9
# # of episode :5600, avg score : 3207.6
# # of episode :5620, avg score : 238.1
# # of episode :5640, avg score : 245.4
# # of episode :5660, avg score : 246.1
# # of episode :5680, avg score : 238.8
# # of episode :5700, avg score : 293.3
# # of episode :5720, avg score : 278.1
# # of episode :5740, avg score : 477.8
# # of episode :5760, avg score : 184.6
# # of episode :5780, avg score : 238.7
# # of episode :5800, avg score : 295.6
# # of episode :5820, avg score : 249.4
# # of episode :5840, avg score : 208.2
# # of episode :5860, avg score : 217.2
# # of episode :5880, avg score : 181.4
# # of episode :5900, avg score : 165.1
# # of episode :5920, avg score : 225.3
# # of episode :5940, avg score : 459.6
# # of episode :5960, avg score : 495.4
# # of episode :5980, avg score : 404.4
# # of episode :6000, avg score : 194.9
# # of episode :6020, avg score : 347.6
# # of episode :6040, avg score : 242.2
# # of episode :6060, avg score : 318.3
# # of episode :6080, avg score : 236.8
# # of episode :6100, avg score : 6230.8
# # of episode :6120, avg score : 420.6
# # of episode :6140, avg score : 313.6
# # of episode :6160, avg score : 272.9
# # of episode :6180, avg score : 355.2
# # of episode :6200, avg score : 194.5
# # of episode :6220, avg score : 107.4
# # of episode :6240, avg score : 83.1
# # of episode :6260, avg score : 92.0
# # of episode :6280, avg score : 113.9
# # of episode :6300, avg score : 120.7
# # of episode :6320, avg score : 131.2
# # of episode :6340, avg score : 150.8
# # of episode :6360, avg score : 320.1
# # of episode :6380, avg score : 195.7
# # of episode :6400, avg score : 160.0
# # of episode :6420, avg score : 151.1
# # of episode :6440, avg score : 144.1
# # of episode :6460, avg score : 151.3
# # of episode :6480, avg score : 161.2
# # of episode :6500, avg score : 181.3
# # of episode :6520, avg score : 304.4
# # of episode :6540, avg score : 250.2
# # of episode :6560, avg score : 236.2
# # of episode :6580, avg score : 327.9
# # of episode :6600, avg score : 167.3
# # of episode :6620, avg score : 218.2
# # of episode :6640, avg score : 191.4
# # of episode :6660, avg score : 262.6
# # of episode :6680, avg score : 403.0
# # of episode :6700, avg score : 275.6
# # of episode :6720, avg score : 227.6
# # of episode :6740, avg score : 215.7
# # of episode :6760, avg score : 267.0
# # of episode :6780, avg score : 380.3
# # of episode :6800, avg score : 399.6
# # of episode :6820, avg score : 562.2
# # of episode :6840, avg score : 661.9
# # of episode :6860, avg score : 425.2
# # of episode :6880, avg score : 509.2
# # of episode :6900, avg score : 89.3
# # of episode :6920, avg score : 56.7
# # of episode :6940, avg score : 68.2
# # of episode :6960, avg score : 102.0
# # of episode :6980, avg score : 138.6
# # of episode :7000, avg score : 166.9
# # of episode :7020, avg score : 455.4
# # of episode :7040, avg score : 150.4
# # of episode :7060, avg score : 807.2
# # of episode :7080, avg score : 6488.8
# # of episode :7100, avg score : 113.6
# # of episode :7120, avg score : 131.0
# # of episode :7140, avg score : 84.8
# # of episode :7160, avg score : 140.6
# # of episode :7180, avg score : 145.2
# # of episode :7200, avg score : 306.4
# # of episode :7220, avg score : 341.2
# # of episode :7240, avg score : 5056.9
# # of episode :7260, avg score : 4735.4
# # of episode :7280, avg score : 211.8
# # of episode :7300, avg score : 349.3
# # of episode :7320, avg score : 701.0
# # of episode :7340, avg score : 1045.1
# # of episode :7360, avg score : 150.2
# # of episode :7380, avg score : 128.3
# # of episode :7400, avg score : 115.0
# # of episode :7420, avg score : 116.8
# # of episode :7440, avg score : 116.2
# # of episode :7460, avg score : 114.8
# # of episode :7480, avg score : 107.8
# # of episode :7500, avg score : 135.5
# # of episode :7520, avg score : 146.8
# # of episode :7540, avg score : 155.8
# # of episode :7560, avg score : 172.2
# # of episode :7580, avg score : 280.9
# # of episode :7600, avg score : 243.2
# # of episode :7620, avg score : 293.9
# # of episode :7640, avg score : 357.9
# # of episode :7660, avg score : 121.2
# # of episode :7680, avg score : 54.4
# # of episode :7700, avg score : 75.4
# # of episode :7720, avg score : 76.5
# # of episode :7740, avg score : 83.6
# # of episode :7760, avg score : 100.8
# # of episode :7780, avg score : 124.8
# # of episode :7800, avg score : 133.2
# # of episode :7820, avg score : 136.5
# # of episode :7840, avg score : 136.7
# # of episode :7860, avg score : 144.0
# # of episode :7880, avg score : 167.9
# # of episode :7900, avg score : 233.6
# # of episode :7920, avg score : 202.7
# # of episode :7940, avg score : 119.1
# # of episode :7960, avg score : 129.4
# # of episode :7980, avg score : 141.1
# # of episode :8000, avg score : 156.0
# # of episode :8020, avg score : 162.0
# # of episode :8040, avg score : 157.2
# # of episode :8060, avg score : 172.3
# # of episode :8080, avg score : 213.2
# # of episode :8100, avg score : 431.2
# # of episode :8120, avg score : 1875.8
# # of episode :8140, avg score : 2014.5
# # of episode :8160, avg score : 376.8
# # of episode :8180, avg score : 97.2
# # of episode :8200, avg score : 110.2
# # of episode :8220, avg score : 136.2
# # of episode :8240, avg score : 155.7
# # of episode :8260, avg score : 117.2
# # of episode :8280, avg score : 124.8
# # of episode :8300, avg score : 159.1
# # of episode :8320, avg score : 258.0
# # of episode :8340, avg score : 732.0
# # of episode :8360, avg score : 191.6
# # of episode :8380, avg score : 252.3
# # of episode :8400, avg score : 526.0
# # of episode :8420, avg score : 145.2
# # of episode :8440, avg score : 116.5
# # of episode :8460, avg score : 130.4
# # of episode :8480, avg score : 140.3
# # of episode :8500, avg score : 164.7
# # of episode :8520, avg score : 199.3
# # of episode :8540, avg score : 601.3
# # of episode :8560, avg score : 477.4
# # of episode :8580, avg score : 393.6
# # of episode :8600, avg score : 1021.5
# # of episode :8620, avg score : 330.3
# # of episode :8640, avg score : 568.6
# # of episode :8660, avg score : 476.2
# # of episode :8680, avg score : 452.8
# # of episode :8700, avg score : 636.1
# # of episode :8720, avg score : 696.0
# # of episode :8740, avg score : 334.1
# # of episode :8760, avg score : 432.6
# # of episode :8780, avg score : 207.2
# # of episode :8800, avg score : 185.7
# # of episode :8820, avg score : 172.6
# # of episode :8840, avg score : 146.5
# # of episode :8860, avg score : 130.1
# # of episode :8880, avg score : 117.0
# # of episode :8900, avg score : 116.2
# # of episode :8920, avg score : 129.0
# # of episode :8940, avg score : 139.9
# # of episode :8960, avg score : 164.8
# # of episode :8980, avg score : 205.6
# # of episode :9000, avg score : 284.8
# # of episode :9020, avg score : 359.4
# # of episode :9040, avg score : 377.4
# # of episode :9060, avg score : 439.4
# # of episode :9080, avg score : 914.7
# # of episode :9100, avg score : 792.5
# # of episode :9120, avg score : 641.5
# # of episode :9140, avg score : 330.0
# # of episode :9160, avg score : 539.9
# # of episode :9180, avg score : 239.1
# # of episode :9200, avg score : 181.8
# # of episode :9220, avg score : 171.8
# # of episode :9240, avg score : 153.2
# # of episode :9260, avg score : 140.2
# # of episode :9280, avg score : 139.2
# # of episode :9300, avg score : 173.2
# # of episode :9320, avg score : 221.1
# # of episode :9340, avg score : 404.1
# # of episode :9360, avg score : 260.4
# # of episode :9380, avg score : 243.4
# # of episode :9400, avg score : 497.7
# # of episode :9420, avg score : 377.9
# # of episode :9440, avg score : 752.2
# # of episode :9460, avg score : 432.5
# # of episode :9480, avg score : 1752.0
# # of episode :9500, avg score : 6414.8
# # of episode :9520, avg score : 1496.3
# # of episode :9540, avg score : 2221.3
# # of episode :9560, avg score : 421.2
# # of episode :9580, avg score : 212.9
# # of episode :9600, avg score : 243.8
# # of episode :9620, avg score : 260.4
# # of episode :9640, avg score : 314.8
# # of episode :9660, avg score : 372.3
# # of episode :9680, avg score : 283.9
# # of episode :9700, avg score : 270.0
# # of episode :9720, avg score : 400.4
# # of episode :9740, avg score : 682.8
# # of episode :9760, avg score : 251.8
# # of episode :9780, avg score : 213.2
# # of episode :9800, avg score : 181.9
# # of episode :9820, avg score : 183.3
# # of episode :9840, avg score : 178.6
# # of episode :9860, avg score : 160.6
# # of episode :9880, avg score : 166.1
# # of episode :9900, avg score : 193.2
# # of episode :9920, avg score : 420.4
# # of episode :9940, avg score : 347.3
# # of episode :9960, avg score : 571.4
# # of episode :9980, avg score : 1703.0
