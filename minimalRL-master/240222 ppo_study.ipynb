# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import time  # 시간 측정을 위한 모듈

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 50
T_horizon     = 100

class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []
        
        self.fc1   = nn.Linear(4,256)
        self.fc_pi = nn.Linear(256,2)
        self.fc_v  = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x, softmax_dim = 0 ):# softmax_dim 0 (inference) or 1(training, batch state input)
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
      
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition
            
            s_lst.append(s) # shape 처리 시 유의 (numpy array)
            a_lst.append([a]) # value
            r_lst.append([r]) # value
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
            
        s,a,r,s_prime,done_mask, prob_a = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                          torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
                                          torch.tensor(done_lst, dtype=torch.float), torch.tensor(prob_a_lst)
        self.data = []
        return s, a, r, s_prime, done_mask, prob_a # batch 출력
        
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()

        for i in range(K_epoch):# 업데이트를 K_epoch 만큼 진행  
            # ==== GAE 구현 ==== #
            td_target = r + gamma * self.v(s_prime) * done_mask # 여기를 배치로 처리하는 것이 핵심
            delta = td_target - self.v(s) # NN (v)를 한번에 불러서 계산 (속도향상)
            delta = delta.detach().numpy()

            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]: # delta vector에서 마지막부터 꺼내어씀 
                advantage = gamma * lmbda * advantage + delta_t[0] # NN 호출이 없으니 for loop 
                advantage_lst.append([advantage])
            advantage_lst.reverse() 
            advantage = torch.tensor(advantage_lst, dtype=torch.float)
            # ====================#
            

            # ==== Clipped Loss ==== #
            pi = self.pi(s, softmax_dim=1)
            pi_a = pi.gather(1,a)
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))  # a/b == exp(log(a)-log(b))

            surr1 = ratio * advantage # surrogate loss (tensor)
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s) , td_target.detach())
            # ====================#

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

# %%
env = gym.make('CartPole-v1')
model = PPO()
score = 0.0
print_interval = 20

for n_epi in range(10000):
    start_time = time.time()  # 에피소드 시작 시간 기록
    s, _ = env.reset()
    done = False
    while not done:
        for t in range(T_horizon):            

            prob = model.pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample().item()
            s_prime, r, done, truncated, info = env.step(a)

            model.put_data((s, a, r/100.0, s_prime, prob[a].item(), done)) 
            s = s_prime

            score += r
            if done:
                break

        model.train_net()
        
    end_time = time.time()  # 에피소드 종료 시간 기록
    episode_duration = end_time - start_time  # 소요 시간 계산

    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode: {}, avg score: {:.1f}, duration: {:.2f} sec".format(n_epi, score/print_interval, episode_duration))
        score = 0.0

env.close()
# Out:
# # of episode: 20, avg score: 21.4, duration: 0.04 sec
# # of episode: 40, avg score: 17.2, duration: 0.04 sec
# # of episode: 60, avg score: 14.9, duration: 0.03 sec
# # of episode: 80, avg score: 13.5, duration: 0.04 sec
# # of episode: 100, avg score: 12.3, duration: 0.04 sec
# # of episode: 120, avg score: 13.1, duration: 0.04 sec
# # of episode: 140, avg score: 12.8, duration: 0.04 sec
# # of episode: 160, avg score: 13.2, duration: 0.03 sec
# # of episode: 180, avg score: 14.4, duration: 0.04 sec
# # of episode: 200, avg score: 14.1, duration: 0.03 sec
# # of episode: 220, avg score: 11.9, duration: 0.04 sec
# # of episode: 240, avg score: 14.6, duration: 0.04 sec
# # of episode: 260, avg score: 23.7, duration: 0.04 sec
# # of episode: 280, avg score: 25.2, duration: 0.04 sec
# # of episode: 300, avg score: 83.8, duration: 0.12 sec
# # of episode: 320, avg score: 200.8, duration: 0.17 sec
# # of episode: 340, avg score: 367.9, duration: 0.68 sec
# # of episode: 360, avg score: 1052.0, duration: 0.54 sec
# # of episode: 380, avg score: 5708.1, duration: 1.42 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 15
#      13 prob = model.pi(torch.from_numpy(s).float())
#      14 m = Categorical(prob)
# ---> 15 a = m.sample().item()
#      16 s_prime, r, done, truncated, info = env.step(a)
#      18 model.put_data((s, a, r/100.0, s_prime, prob[a].item(), done))
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\torch\distributions\categorical.py:118, in Categorical.sample(self, sample_shape)
#     116     sample_shape = torch.Size(sample_shape)
#     117 probs_2d = self.probs.reshape(-1, self._num_events)
# --> 118 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     119 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# KeyboardInterrupt:

# %% [markdown]
# # GPU버전으로 수정

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 50
T_horizon     = 100

class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []
        
        self.fc1   = nn.Linear(4,256)
        self.fc_pi = nn.Linear(256,2)
        self.fc_v  = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x, softmax_dim = 0 ):# softmax_dim 0 (inference) or 1(training, batch state input)
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
      
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition

            # 여기서 s와 s_prime을 PyTorch 텐서로 변환합니다.
            s = torch.from_numpy(s).float() if isinstance(s, np.ndarray) else s
            s_prime = torch.from_numpy(s_prime).float() if isinstance(s_prime, np.ndarray) else s_prime

            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])

        s, a, r, s_prime, done_mask, prob_a = torch.stack(s_lst, dim=0).to(device), \
                                              torch.tensor(a_lst, dtype=torch.int64).to(device), \
                                              torch.tensor(r_lst, dtype=torch.float).to(device), \
                                              torch.stack(s_prime_lst, dim=0).to(device), \
                                              torch.tensor(done_lst, dtype=torch.float).to(device), \
                                              torch.tensor(prob_a_lst, dtype=torch.float).to(device)
        self.data = []
        return s, a, r, s_prime, done_mask, prob_a

        
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()

        for i in range(K_epoch):# 업데이트를 K_epoch 만큼 진행  
            # ==== GAE 구현 ==== #
            td_target = r + gamma * self.v(s_prime) * done_mask # 여기를 배치로 처리하는 것이 핵심
            delta = td_target - self.v(s) # NN (v)를 한번에 불러서 계산 (속도향상)
            delta = delta.detach().cpu().numpy()

            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]: # delta vector에서 마지막부터 꺼내어씀 
                advantage = gamma * lmbda * advantage + delta_t[0] # NN 호출이 없으니 for loop 
                advantage_lst.append([advantage])
            advantage_lst.reverse() 
            advantage = torch.tensor(advantage_lst, dtype=torch.float).to(device)
            # ====================#
            

            # ==== Clipped Loss ==== #
            pi = self.pi(s, softmax_dim=1)
            pi_a = pi.gather(1,a)
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))  # a/b == exp(log(a)-log(b))

            surr1 = ratio * advantage # surrogate loss (tensor)
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s) , td_target.detach())
            # ====================#

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

# %%
env = gym.make('CartPole-v1')
model = PPO().to(device)
score = 0.0
print_interval = 20

for n_epi in range(10000):
    start_time = time.time()  # 에피소드 시작 시간 기록
    s, _ = env.reset()
    done = False
    while not done:
        for t in range(T_horizon):
            s = torch.from_numpy(s).float().to(device)
            prob = model.pi(s)
            m = Categorical(prob)
            a = m.sample().item()
            s_prime, r, done, truncated, info = env.step(a)

            model.put_data((s, a, r/100.0, s_prime, prob[a].item(), done)) 
            s = s_prime

            score += r
            if done:
                break

        model.train_net()
        
    end_time = time.time()  # 에피소드 종료 시간 기록
    episode_duration = end_time - start_time  # 소요 시간 계산

    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode: {}, avg score: {:.1f}, duration: {:.2f} sec".format(n_epi, score/print_interval, episode_duration))
        score = 0.0        

env.close()
# Out:
# # of episode: 20, avg score: 24.9, duration: 0.10 sec
# # of episode: 40, avg score: 13.7, duration: 0.11 sec
# # of episode: 60, avg score: 15.9, duration: 0.09 sec
# # of episode: 80, avg score: 19.3, duration: 0.10 sec
# # of episode: 100, avg score: 12.2, duration: 0.09 sec
# # of episode: 120, avg score: 13.4, duration: 0.08 sec
# # of episode: 140, avg score: 12.9, duration: 0.09 sec
# # of episode: 160, avg score: 17.4, duration: 0.12 sec
# # of episode: 180, avg score: 21.4, duration: 0.09 sec
# # of episode: 200, avg score: 25.7, duration: 0.10 sec
# # of episode: 220, avg score: 50.5, duration: 0.11 sec
# # of episode: 240, avg score: 84.6, duration: 0.17 sec
# # of episode: 260, avg score: 121.5, duration: 0.53 sec
# # of episode: 280, avg score: 183.8, duration: 0.31 sec
# # of episode: 300, avg score: 171.4, duration: 0.37 sec
# # of episode: 320, avg score: 378.4, duration: 0.37 sec
# # of episode: 340, avg score: 1114.3, duration: 0.13 sec
# # of episode: 360, avg score: 446.1, duration: 0.53 sec
# # of episode: 380, avg score: 3873.3, duration: 0.72 sec
# # of episode: 400, avg score: 1936.5, duration: 3.93 sec
# # of episode: 420, avg score: 5797.9, duration: 2.39 sec
# # of episode: 440, avg score: 600.9, duration: 0.77 sec
# # of episode: 460, avg score: 675.8, duration: 0.50 sec
# # of episode: 480, avg score: 5528.1, duration: 64.37 sec
# # of episode: 500, avg score: 7488.9, duration: 1.09 sec
# # of episode: 520, avg score: 1644.7, duration: 1.14 sec
# # of episode: 540, avg score: 7687.0, duration: 0.60 sec
# # of episode: 560, avg score: 557.0, duration: 0.54 sec
# # of episode: 580, avg score: 20575.0, duration: 1.18 sec
# # of episode: 600, avg score: 2898.7, duration: 0.37 sec
# # of episode: 620, avg score: 1103.2, duration: 0.77 sec
# # of episode: 640, avg score: 7959.6, duration: 0.41 sec
# # of episode: 660, avg score: 227.5, duration: 0.42 sec
# # of episode: 680, avg score: 242.8, duration: 0.38 sec
# # of episode: 700, avg score: 275.6, duration: 0.48 sec
# # of episode: 720, avg score: 396.4, duration: 0.60 sec
# # of episode: 740, avg score: 489.2, duration: 0.09 sec
# # of episode: 760, avg score: 127.4, duration: 0.28 sec
# # of episode: 780, avg score: 125.6, duration: 0.08 sec
# # of episode: 800, avg score: 165.7, duration: 0.42 sec
# # of episode: 820, avg score: 158.5, duration: 0.28 sec
# # of episode: 840, avg score: 1222.9, duration: 0.85 sec
# # of episode: 860, avg score: 1850.1, duration: 0.79 sec
# # of episode: 880, avg score: 6020.7, duration: 0.60 sec
# # of episode: 900, avg score: 271.6, duration: 0.39 sec
# # of episode: 920, avg score: 451.0, duration: 0.64 sec
# # of episode: 940, avg score: 7525.4, duration: 0.44 sec
# # of episode: 960, avg score: 1023.9, duration: 0.27 sec
# # of episode: 980, avg score: 174.1, duration: 0.22 sec
# # of episode: 1000, avg score: 210.2, duration: 0.39 sec
# # of episode: 1020, avg score: 382.0, duration: 0.25 sec
# # of episode: 1040, avg score: 106.9, duration: 0.25 sec
# # of episode: 1060, avg score: 138.7, duration: 0.33 sec
# # of episode: 1080, avg score: 997.9, duration: 21.89 sec
# # of episode: 1100, avg score: 110.4, duration: 0.30 sec
# # of episode: 1120, avg score: 348.2, duration: 0.44 sec
# # of episode: 1140, avg score: 243.7, duration: 0.49 sec
# # of episode: 1160, avg score: 264.6, duration: 0.24 sec
# # of episode: 1180, avg score: 139.4, duration: 0.47 sec
# # of episode: 1200, avg score: 450.4, duration: 4.70 sec
# # of episode: 1220, avg score: 808.5, duration: 0.79 sec
# # of episode: 1240, avg score: 318.4, duration: 0.57 sec
# # of episode: 1260, avg score: 666.9, duration: 5.35 sec
# # of episode: 1280, avg score: 8876.8, duration: 0.82 sec
# # of episode: 1300, avg score: 297.7, duration: 0.42 sec
# # of episode: 1320, avg score: 179.2, duration: 0.36 sec
# # of episode: 1340, avg score: 218.6, duration: 0.46 sec
# # of episode: 1360, avg score: 309.5, duration: 0.77 sec
# # of episode: 1380, avg score: 456.5, duration: 0.69 sec
# # of episode: 1400, avg score: 1739.8, duration: 0.83 sec
# # of episode: 1420, avg score: 3016.8, duration: 1.07 sec
# # of episode: 1440, avg score: 1767.2, duration: 3.97 sec
# # of episode: 1460, avg score: 5407.4, duration: 0.36 sec
# # of episode: 1480, avg score: 259.7, duration: 0.40 sec
# # of episode: 1500, avg score: 254.7, duration: 0.45 sec
# # of episode: 1520, avg score: 217.4, duration: 0.28 sec
# # of episode: 1540, avg score: 198.7, duration: 0.33 sec
# # of episode: 1560, avg score: 204.7, duration: 0.38 sec
# # of episode: 1580, avg score: 194.3, duration: 0.27 sec
# # of episode: 1600, avg score: 187.7, duration: 0.31 sec
# # of episode: 1620, avg score: 172.1, duration: 0.25 sec
# # of episode: 1640, avg score: 164.3, duration: 0.33 sec
# # of episode: 1660, avg score: 172.8, duration: 0.24 sec
# # of episode: 1680, avg score: 157.8, duration: 0.30 sec
# # of episode: 1700, avg score: 163.1, duration: 0.22 sec
# # of episode: 1720, avg score: 157.2, duration: 0.33 sec
# # of episode: 1740, avg score: 163.9, duration: 0.28 sec
# # of episode: 1760, avg score: 176.4, duration: 0.28 sec
# # of episode: 1780, avg score: 155.1, duration: 0.25 sec
# # of episode: 1800, avg score: 139.4, duration: 0.25 sec
# # of episode: 1820, avg score: 126.8, duration: 0.24 sec
# # of episode: 1840, avg score: 134.3, duration: 0.22 sec
# # of episode: 1860, avg score: 149.0, duration: 0.22 sec
# # of episode: 1880, avg score: 156.0, duration: 0.31 sec
# # of episode: 1900, avg score: 162.9, duration: 0.24 sec
# # of episode: 1920, avg score: 172.8, duration: 0.28 sec
# # of episode: 1940, avg score: 178.9, duration: 0.24 sec
# # of episode: 1960, avg score: 172.6, duration: 0.30 sec
# # of episode: 1980, avg score: 159.7, duration: 0.24 sec
# # of episode: 2000, avg score: 170.4, duration: 0.25 sec
# # of episode: 2020, avg score: 176.9, duration: 0.25 sec
# # of episode: 2040, avg score: 186.9, duration: 0.44 sec
# # of episode: 2060, avg score: 244.9, duration: 0.44 sec
# # of episode: 2080, avg score: 2886.2, duration: 0.38 sec
# # of episode: 2100, avg score: 177.8, duration: 0.28 sec
# # of episode: 2120, avg score: 265.9, duration: 0.46 sec
# # of episode: 2140, avg score: 61070.2, duration: 0.64 sec
# # of episode: 2160, avg score: 413.2, duration: 0.79 sec
# # of episode: 2180, avg score: 5009.3, duration: 0.68 sec
# # of episode: 2200, avg score: 328.6, duration: 0.56 sec
# # of episode: 2220, avg score: 282.6, duration: 0.63 sec
# # of episode: 2240, avg score: 262.4, duration: 0.39 sec
# # of episode: 2260, avg score: 445.7, duration: 0.42 sec
# # of episode: 2280, avg score: 387.9, duration: 1.60 sec
# # of episode: 2300, avg score: 949.6, duration: 1.18 sec
# # of episode: 2320, avg score: 416.7, duration: 1.47 sec
# # of episode: 2340, avg score: 569.0, duration: 0.53 sec
# # of episode: 2360, avg score: 371.3, duration: 0.61 sec
# # of episode: 2380, avg score: 335.4, duration: 0.58 sec
# # of episode: 2400, avg score: 417.8, duration: 0.71 sec
# # of episode: 2420, avg score: 37303.2, duration: 0.58 sec
# # of episode: 2440, avg score: 847.2, duration: 0.58 sec
# # of episode: 2460, avg score: 1293.7, duration: 0.58 sec
# # of episode: 2480, avg score: 668.5, duration: 0.66 sec
# # of episode: 2500, avg score: 931.0, duration: 0.60 sec
# # of episode: 2520, avg score: 1338.0, duration: 1.08 sec
# # of episode: 2540, avg score: 399.0, duration: 0.39 sec
# # of episode: 2560, avg score: 325.1, duration: 0.51 sec
# # of episode: 2580, avg score: 6835.6, duration: 107.56 sec
# # of episode: 2600, avg score: 254.3, duration: 0.35 sec
# # of episode: 2620, avg score: 250.6, duration: 0.47 sec
# # of episode: 2640, avg score: 1132.3, duration: 0.36 sec
# # of episode: 2660, avg score: 290.7, duration: 0.39 sec
# # of episode: 2680, avg score: 53219.8, duration: 0.47 sec
# # of episode: 2700, avg score: 188.2, duration: 0.25 sec
# # of episode: 2720, avg score: 174.2, duration: 0.27 sec
# # of episode: 2740, avg score: 188.9, duration: 0.27 sec
# # of episode: 2760, avg score: 195.8, duration: 0.42 sec
# # of episode: 2780, avg score: 230.4, duration: 0.44 sec
# # of episode: 2800, avg score: 255.1, duration: 0.42 sec
# # of episode: 2820, avg score: 368.9, duration: 0.52 sec
# # of episode: 2840, avg score: 394.1, duration: 0.68 sec
# # of episode: 2860, avg score: 1445.2, duration: 0.79 sec
# # of episode: 2880, avg score: 6706.5, duration: 1.66 sec
# # of episode: 2900, avg score: 463.4, duration: 0.38 sec
# # of episode: 2920, avg score: 5866.2, duration: 0.25 sec
# # of episode: 2940, avg score: 512.4, duration: 0.25 sec
# # of episode: 2960, avg score: 1569.0, duration: 4.19 sec
# # of episode: 2980, avg score: 1155.0, duration: 0.66 sec
# # of episode: 3000, avg score: 1294.2, duration: 0.46 sec
# # of episode: 3020, avg score: 402.1, duration: 0.56 sec
# # of episode: 3040, avg score: 277.6, duration: 0.49 sec
# # of episode: 3060, avg score: 352.1, duration: 0.58 sec
# # of episode: 3080, avg score: 2661.8, duration: 0.27 sec
# # of episode: 3100, avg score: 722.3, duration: 1.78 sec
# # of episode: 3120, avg score: 242.6, duration: 0.28 sec
# # of episode: 3140, avg score: 139.9, duration: 0.35 sec
# # of episode: 3160, avg score: 25867.2, duration: 0.67 sec
# # of episode: 3180, avg score: 383.1, duration: 0.47 sec
# # of episode: 3200, avg score: 335.7, duration: 0.50 sec
# # of episode: 3220, avg score: 1080.5, duration: 0.78 sec
# # of episode: 3240, avg score: 8565.4, duration: 0.65 sec
# # of episode: 3260, avg score: 507.5, duration: 0.68 sec
# # of episode: 3280, avg score: 320.6, duration: 0.72 sec
# # of episode: 3300, avg score: 4902.9, duration: 0.09 sec
# # of episode: 3320, avg score: 16.8, duration: 0.09 sec
# # of episode: 3340, avg score: 150.9, duration: 0.39 sec
# # of episode: 3360, avg score: 144.2, duration: 0.28 sec
# # of episode: 3380, avg score: 144.6, duration: 0.28 sec
# # of episode: 3400, avg score: 147.1, duration: 0.39 sec
# # of episode: 3420, avg score: 132.3, duration: 0.38 sec
# # of episode: 3440, avg score: 140.2, duration: 0.08 sec
# # of episode: 3460, avg score: 2680.0, duration: 0.28 sec
# # of episode: 3480, avg score: 5778.9, duration: 0.55 sec
# # of episode: 3500, avg score: 461.6, duration: 0.38 sec
# # of episode: 3520, avg score: 4458.1, duration: 0.53 sec
# # of episode: 3540, avg score: 3831.6, duration: 0.28 sec
# # of episode: 3560, avg score: 407.1, duration: 0.44 sec
# # of episode: 3580, avg score: 3054.6, duration: 1.01 sec
# # of episode: 3600, avg score: 1977.0, duration: 0.39 sec
# # of episode: 3620, avg score: 237.8, duration: 0.24 sec
# # of episode: 3640, avg score: 67.7, duration: 0.25 sec
# # of episode: 3660, avg score: 106.0, duration: 0.24 sec
# # of episode: 3680, avg score: 139.3, duration: 0.25 sec
# # of episode: 3700, avg score: 182.6, duration: 0.38 sec
# # of episode: 3720, avg score: 168.7, duration: 0.27 sec
# # of episode: 3740, avg score: 144.1, duration: 0.25 sec
# # of episode: 3760, avg score: 183.2, duration: 0.36 sec
# # of episode: 3780, avg score: 557.0, duration: 0.38 sec
# # of episode: 3800, avg score: 223.9, duration: 0.69 sec
# # of episode: 3820, avg score: 1803.2, duration: 0.47 sec
# # of episode: 3840, avg score: 1331.2, duration: 0.42 sec
# # of episode: 3860, avg score: 224.7, duration: 0.38 sec
# # of episode: 3880, avg score: 196.2, duration: 0.28 sec
# # of episode: 3900, avg score: 195.8, duration: 0.28 sec
# # of episode: 3920, avg score: 179.9, duration: 0.28 sec
# # of episode: 3940, avg score: 162.8, duration: 0.30 sec
# # of episode: 3960, avg score: 162.8, duration: 0.25 sec
# # of episode: 3980, avg score: 171.4, duration: 0.27 sec
# # of episode: 4000, avg score: 177.9, duration: 0.35 sec
# # of episode: 4020, avg score: 217.8, duration: 0.25 sec
# # of episode: 4040, avg score: 224.2, duration: 0.42 sec
# # of episode: 4060, avg score: 215.0, duration: 0.23 sec
# # of episode: 4080, avg score: 250.2, duration: 0.35 sec
# # of episode: 4100, avg score: 219.8, duration: 0.44 sec
# # of episode: 4120, avg score: 264.6, duration: 0.56 sec
# # of episode: 4140, avg score: 225.9, duration: 0.41 sec
# # of episode: 4160, avg score: 213.6, duration: 0.29 sec
# # of episode: 4180, avg score: 201.4, duration: 0.41 sec
# # of episode: 4200, avg score: 226.3, duration: 0.24 sec
# # of episode: 4220, avg score: 207.9, duration: 0.27 sec
# # of episode: 4240, avg score: 279.4, duration: 0.47 sec
# # of episode: 4260, avg score: 301.8, duration: 0.35 sec
# # of episode: 4280, avg score: 288.9, duration: 0.51 sec
# # of episode: 4300, avg score: 284.2, duration: 0.34 sec
# # of episode: 4320, avg score: 258.1, duration: 0.40 sec
# # of episode: 4340, avg score: 228.7, duration: 0.30 sec
# # of episode: 4360, avg score: 195.7, duration: 0.39 sec
# # of episode: 4380, avg score: 188.6, duration: 0.28 sec
# # of episode: 4400, avg score: 218.7, duration: 0.71 sec
# # of episode: 4420, avg score: 347.6, duration: 0.30 sec
# # of episode: 4440, avg score: 383.4, duration: 0.74 sec
# # of episode: 4460, avg score: 411.1, duration: 0.83 sec
# # of episode: 4480, avg score: 431.8, duration: 0.49 sec
# # of episode: 4500, avg score: 381.4, duration: 0.30 sec
# # of episode: 4520, avg score: 447.7, duration: 0.46 sec
# # of episode: 4540, avg score: 478.1, duration: 0.50 sec
# # of episode: 4560, avg score: 566.2, duration: 0.74 sec
# # of episode: 4580, avg score: 359.9, duration: 0.96 sec
# # of episode: 4600, avg score: 446.9, duration: 0.41 sec
# # of episode: 4620, avg score: 256.9, duration: 0.39 sec
# # of episode: 4640, avg score: 186.8, duration: 0.28 sec
# # of episode: 4660, avg score: 177.3, duration: 0.28 sec
# # of episode: 4680, avg score: 194.1, duration: 0.41 sec
# # of episode: 4700, avg score: 281.8, duration: 0.49 sec
# # of episode: 4720, avg score: 3472.9, duration: 0.14 sec
# # of episode: 4740, avg score: 111.9, duration: 0.25 sec
# # of episode: 4760, avg score: 392.8, duration: 0.82 sec
# # of episode: 4780, avg score: 5643.3, duration: 0.49 sec
# # of episode: 4800, avg score: 745.0, duration: 0.47 sec
# # of episode: 4820, avg score: 323.7, duration: 0.54 sec
# # of episode: 4840, avg score: 275.9, duration: 0.44 sec
# # of episode: 4860, avg score: 70.8, duration: 0.30 sec
# # of episode: 4880, avg score: 70.3, duration: 0.08 sec
# # of episode: 4900, avg score: 129.1, duration: 0.07 sec
# # of episode: 4920, avg score: 171.8, duration: 0.22 sec
# # of episode: 4940, avg score: 101.6, duration: 0.10 sec
# # of episode: 4960, avg score: 91.2, duration: 0.13 sec
# # of episode: 4980, avg score: 2699.2, duration: 74.88 sec
# # of episode: 5000, avg score: 4103.1, duration: 0.35 sec
# # of episode: 5020, avg score: 179.7, duration: 0.30 sec
# # of episode: 5040, avg score: 163.2, duration: 0.25 sec
# # of episode: 5060, avg score: 172.8, duration: 0.24 sec
# # of episode: 5080, avg score: 1087.4, duration: 0.57 sec
# # of episode: 5100, avg score: 315.9, duration: 0.37 sec
# # of episode: 5120, avg score: 238.9, duration: 0.36 sec
# # of episode: 5140, avg score: 232.7, duration: 0.36 sec
# # of episode: 5160, avg score: 233.9, duration: 0.36 sec
# # of episode: 5180, avg score: 238.8, duration: 0.43 sec
# # of episode: 5200, avg score: 209.9, duration: 0.27 sec
# # of episode: 5220, avg score: 199.8, duration: 0.41 sec
# # of episode: 5240, avg score: 203.9, duration: 0.31 sec
# # of episode: 5260, avg score: 194.2, duration: 0.27 sec
# # of episode: 5280, avg score: 190.1, duration: 0.28 sec
# # of episode: 5300, avg score: 194.1, duration: 0.25 sec
# # of episode: 5320, avg score: 241.1, duration: 0.27 sec
# # of episode: 5340, avg score: 183.5, duration: 0.28 sec
# # of episode: 5360, avg score: 176.1, duration: 0.27 sec
# # of episode: 5380, avg score: 153.6, duration: 0.28 sec
# # of episode: 5400, avg score: 153.7, duration: 0.25 sec
# # of episode: 5420, avg score: 146.7, duration: 0.24 sec
# # of episode: 5440, avg score: 134.6, duration: 0.23 sec
# # of episode: 5460, avg score: 127.8, duration: 0.24 sec
# # of episode: 5480, avg score: 127.5, duration: 0.27 sec
# # of episode: 5500, avg score: 133.2, duration: 0.27 sec
# # of episode: 5520, avg score: 141.2, duration: 0.27 sec
# # of episode: 5540, avg score: 135.7, duration: 0.25 sec
# # of episode: 5560, avg score: 135.6, duration: 0.28 sec
# # of episode: 5580, avg score: 131.4, duration: 0.22 sec
# # of episode: 5600, avg score: 126.5, duration: 0.22 sec
# # of episode: 5620, avg score: 124.8, duration: 0.20 sec
# # of episode: 5640, avg score: 128.7, duration: 0.22 sec
# # of episode: 5660, avg score: 133.4, duration: 0.31 sec
# # of episode: 5680, avg score: 130.7, duration: 0.23 sec
# # of episode: 5700, avg score: 120.5, duration: 0.25 sec
# # of episode: 5720, avg score: 117.6, duration: 0.22 sec
# # of episode: 5740, avg score: 110.9, duration: 0.28 sec
# # of episode: 5760, avg score: 115.5, duration: 0.24 sec
# # of episode: 5780, avg score: 116.8, duration: 0.25 sec
# # of episode: 5800, avg score: 104.6, duration: 0.27 sec
# # of episode: 5820, avg score: 94.8, duration: 0.22 sec
# # of episode: 5840, avg score: 96.3, duration: 0.27 sec
# # of episode: 5860, avg score: 102.2, duration: 0.27 sec
# # of episode: 5880, avg score: 113.7, duration: 0.22 sec
# # of episode: 5900, avg score: 77.8, duration: 0.09 sec
# # of episode: 5920, avg score: 102.7, duration: 0.23 sec
# # of episode: 5940, avg score: 110.2, duration: 0.08 sec
# # of episode: 5960, avg score: 111.6, duration: 0.27 sec
# # of episode: 5980, avg score: 120.4, duration: 0.24 sec
# # of episode: 6000, avg score: 114.2, duration: 0.24 sec
# # of episode: 6020, avg score: 95.4, duration: 0.21 sec
# # of episode: 6040, avg score: 89.0, duration: 0.13 sec
# # of episode: 6060, avg score: 88.2, duration: 0.12 sec
# # of episode: 6080, avg score: 94.7, duration: 0.21 sec
# # of episode: 6100, avg score: 90.5, duration: 0.11 sec
# # of episode: 6120, avg score: 96.8, duration: 0.24 sec
# # of episode: 6140, avg score: 97.8, duration: 0.25 sec
# # of episode: 6160, avg score: 88.0, duration: 0.27 sec
# # of episode: 6180, avg score: 85.8, duration: 0.24 sec
# # of episode: 6200, avg score: 93.5, duration: 0.24 sec
# # of episode: 6220, avg score: 99.8, duration: 0.20 sec
# # of episode: 6240, avg score: 105.4, duration: 0.22 sec
# # of episode: 6260, avg score: 76.8, duration: 0.08 sec
# # of episode: 6280, avg score: 97.7, duration: 0.27 sec
# # of episode: 6300, avg score: 88.8, duration: 0.09 sec
# # of episode: 6320, avg score: 91.9, duration: 0.14 sec
# # of episode: 6340, avg score: 91.8, duration: 0.14 sec
# # of episode: 6360, avg score: 78.2, duration: 0.15 sec
# # of episode: 6380, avg score: 104.2, duration: 0.22 sec
# # of episode: 6400, avg score: 107.8, duration: 0.27 sec
# # of episode: 6420, avg score: 94.1, duration: 0.08 sec
# # of episode: 6440, avg score: 37.7, duration: 0.09 sec
# # of episode: 6460, avg score: 55.4, duration: 0.24 sec
# # of episode: 6480, avg score: 84.2, duration: 0.11 sec
# # of episode: 6500, avg score: 81.0, duration: 0.08 sec
# # of episode: 6520, avg score: 102.0, duration: 0.27 sec
# # of episode: 6540, avg score: 119.8, duration: 0.25 sec
# # of episode: 6560, avg score: 139.5, duration: 0.25 sec
# # of episode: 6580, avg score: 133.9, duration: 0.22 sec
# # of episode: 6600, avg score: 129.2, duration: 0.22 sec
# # of episode: 6620, avg score: 126.1, duration: 0.22 sec
# # of episode: 6640, avg score: 126.2, duration: 0.22 sec
# # of episode: 6660, avg score: 106.7, duration: 0.09 sec
# # of episode: 6680, avg score: 67.5, duration: 0.14 sec
# # of episode: 6700, avg score: 99.3, duration: 0.13 sec
# # of episode: 6720, avg score: 96.2, duration: 0.27 sec
# # of episode: 6740, avg score: 102.2, duration: 0.25 sec
# # of episode: 6760, avg score: 104.0, duration: 0.22 sec
# # of episode: 6780, avg score: 103.7, duration: 0.22 sec
# # of episode: 6800, avg score: 109.7, duration: 0.20 sec
# # of episode: 6820, avg score: 109.0, duration: 0.25 sec
# # of episode: 6840, avg score: 121.0, duration: 0.25 sec
# # of episode: 6860, avg score: 128.7, duration: 0.25 sec
# # of episode: 6880, avg score: 148.8, duration: 0.28 sec
# # of episode: 6900, avg score: 179.6, duration: 0.33 sec
# # of episode: 6920, avg score: 221.3, duration: 0.36 sec
# # of episode: 6940, avg score: 203.1, duration: 0.25 sec
# # of episode: 6960, avg score: 166.1, duration: 0.25 sec
# # of episode: 6980, avg score: 157.2, duration: 0.29 sec
# # of episode: 7000, avg score: 145.1, duration: 0.24 sec
# # of episode: 7020, avg score: 139.7, duration: 0.25 sec
# # of episode: 7040, avg score: 135.7, duration: 0.24 sec
# # of episode: 7060, avg score: 126.6, duration: 0.27 sec
# # of episode: 7080, avg score: 125.3, duration: 0.24 sec
# # of episode: 7100, avg score: 136.2, duration: 0.25 sec
# # of episode: 7120, avg score: 138.7, duration: 0.25 sec
# # of episode: 7140, avg score: 140.4, duration: 0.26 sec
# # of episode: 7160, avg score: 141.8, duration: 0.29 sec
# # of episode: 7180, avg score: 137.8, duration: 0.24 sec
# # of episode: 7200, avg score: 149.2, duration: 0.24 sec
# # of episode: 7220, avg score: 157.9, duration: 0.26 sec
# # of episode: 7240, avg score: 181.6, duration: 0.27 sec
# # of episode: 7260, avg score: 169.8, duration: 0.25 sec
# # of episode: 7280, avg score: 166.7, duration: 0.30 sec
# # of episode: 7300, avg score: 163.8, duration: 0.26 sec
# # of episode: 7320, avg score: 159.7, duration: 0.35 sec
# # of episode: 7340, avg score: 155.7, duration: 0.24 sec
# # of episode: 7360, avg score: 157.2, duration: 0.27 sec
# # of episode: 7380, avg score: 144.1, duration: 0.36 sec
# # of episode: 7400, avg score: 164.2, duration: 0.13 sec
# # of episode: 7420, avg score: 144.5, duration: 0.38 sec
# # of episode: 7440, avg score: 170.9, duration: 0.41 sec
# # of episode: 7460, avg score: 268.1, duration: 0.71 sec
# # of episode: 7480, avg score: 395.9, duration: 1.66 sec
# # of episode: 7500, avg score: 6999.6, duration: 0.14 sec
# # of episode: 7520, avg score: 4292.9, duration: 2.64 sec
# # of episode: 7540, avg score: 9789.4, duration: 0.38 sec
# # of episode: 7560, avg score: 327.9, duration: 0.55 sec
# # of episode: 7580, avg score: 317.6, duration: 0.39 sec
# # of episode: 7600, avg score: 1987.7, duration: 0.09 sec
# # of episode: 7620, avg score: 325.5, duration: 0.13 sec
# # of episode: 7640, avg score: 200.7, duration: 2.04 sec
# # of episode: 7660, avg score: 1902.2, duration: 0.50 sec
# # of episode: 7680, avg score: 322.6, duration: 0.55 sec
# # of episode: 7700, avg score: 476.9, duration: 1.13 sec
# # of episode: 7720, avg score: 532.4, duration: 0.85 sec
# # of episode: 7740, avg score: 575.7, duration: 0.63 sec
# # of episode: 7760, avg score: 402.6, duration: 0.61 sec
# # of episode: 7780, avg score: 283.8, duration: 0.43 sec
# # of episode: 7800, avg score: 263.4, duration: 0.37 sec
# # of episode: 7820, avg score: 290.5, duration: 0.52 sec
# # of episode: 7840, avg score: 381.8, duration: 0.57 sec
# # of episode: 7860, avg score: 319.2, duration: 0.22 sec
# # of episode: 7880, avg score: 255.6, duration: 0.39 sec
# # of episode: 7900, avg score: 203.4, duration: 0.39 sec
# # of episode: 7920, avg score: 200.2, duration: 0.24 sec
# # of episode: 7940, avg score: 229.8, duration: 0.42 sec
# # of episode: 7960, avg score: 290.6, duration: 0.58 sec
# # of episode: 7980, avg score: 483.2, duration: 0.74 sec
# # of episode: 8000, avg score: 744.1, duration: 2.06 sec
# # of episode: 8020, avg score: 891.5, duration: 1.07 sec
# # of episode: 8040, avg score: 511.9, duration: 0.99 sec
# # of episode: 8060, avg score: 736.8, duration: 0.60 sec
# # of episode: 8080, avg score: 437.1, duration: 0.75 sec
# # of episode: 8100, avg score: 415.4, duration: 0.96 sec
# # of episode: 8120, avg score: 1001.8, duration: 1.18 sec
# # of episode: 8140, avg score: 561.4, duration: 0.09 sec
# # of episode: 8160, avg score: 25.6, duration: 0.08 sec
# # of episode: 8180, avg score: 16.9, duration: 0.08 sec
# # of episode: 8200, avg score: 11.7, duration: 0.08 sec
# # of episode: 8220, avg score: 11.2, duration: 0.08 sec
# # of episode: 8240, avg score: 10.0, duration: 0.08 sec
# # of episode: 8260, avg score: 10.3, duration: 0.08 sec
# # of episode: 8280, avg score: 14.0, duration: 0.09 sec
# # of episode: 8300, avg score: 15.8, duration: 0.10 sec
# # of episode: 8320, avg score: 14.7, duration: 0.09 sec
# # of episode: 8340, avg score: 13.8, duration: 0.09 sec
# # of episode: 8360, avg score: 23.1, duration: 0.09 sec
# # of episode: 8380, avg score: 39.5, duration: 0.13 sec
# # of episode: 8400, avg score: 3273.4, duration: 0.63 sec
# # of episode: 8420, avg score: 982.5, duration: 0.85 sec
# # of episode: 8440, avg score: 319.1, duration: 0.36 sec
# # of episode: 8460, avg score: 244.2, duration: 0.38 sec
# # of episode: 8480, avg score: 227.7, duration: 0.25 sec
# # of episode: 8500, avg score: 173.2, duration: 0.28 sec
# # of episode: 8520, avg score: 160.5, duration: 0.33 sec
# # of episode: 8540, avg score: 152.5, duration: 0.27 sec
# # of episode: 8560, avg score: 117.5, duration: 0.27 sec
# # of episode: 8580, avg score: 77.8, duration: 0.08 sec
# # of episode: 8600, avg score: 136.3, duration: 0.08 sec
# # of episode: 8620, avg score: 88.2, duration: 0.09 sec
# # of episode: 8640, avg score: 89.7, duration: 0.27 sec
# # of episode: 8660, avg score: 91.8, duration: 0.22 sec
# # of episode: 8680, avg score: 89.3, duration: 0.25 sec
# # of episode: 8700, avg score: 71.9, duration: 0.08 sec
# # of episode: 8720, avg score: 57.6, duration: 0.08 sec
# # of episode: 8740, avg score: 69.6, duration: 0.27 sec
# # of episode: 8760, avg score: 91.5, duration: 0.09 sec
# # of episode: 8780, avg score: 63.1, duration: 0.20 sec
# # of episode: 8800, avg score: 24.2, duration: 0.08 sec
# # of episode: 8820, avg score: 14.2, duration: 0.08 sec
# # of episode: 8840, avg score: 9.3, duration: 0.08 sec
# # of episode: 8860, avg score: 9.2, duration: 0.08 sec
# # of episode: 8880, avg score: 9.4, duration: 0.09 sec
# # of episode: 8900, avg score: 9.3, duration: 0.08 sec
# # of episode: 8920, avg score: 9.2, duration: 0.08 sec
# # of episode: 8940, avg score: 9.4, duration: 0.09 sec
# # of episode: 8960, avg score: 9.4, duration: 0.08 sec
# # of episode: 8980, avg score: 9.2, duration: 0.09 sec
# # of episode: 9000, avg score: 9.4, duration: 0.09 sec
# # of episode: 9020, avg score: 9.4, duration: 0.10 sec
# # of episode: 9040, avg score: 9.2, duration: 0.09 sec
# # of episode: 9060, avg score: 9.5, duration: 0.08 sec
# # of episode: 9080, avg score: 9.1, duration: 0.09 sec
# # of episode: 9100, avg score: 9.6, duration: 0.06 sec
# # of episode: 9120, avg score: 9.4, duration: 0.09 sec
# # of episode: 9140, avg score: 9.3, duration: 0.08 sec
# # of episode: 9160, avg score: 9.3, duration: 0.08 sec
# # of episode: 9180, avg score: 9.5, duration: 0.08 sec
# # of episode: 9200, avg score: 9.2, duration: 0.09 sec
# # of episode: 9220, avg score: 9.5, duration: 0.09 sec
# # of episode: 9240, avg score: 9.3, duration: 0.09 sec
# # of episode: 9260, avg score: 9.6, duration: 0.09 sec
# # of episode: 9280, avg score: 9.5, duration: 0.11 sec
# # of episode: 9300, avg score: 9.4, duration: 0.10 sec
# # of episode: 9320, avg score: 9.7, duration: 0.09 sec
# # of episode: 9340, avg score: 9.3, duration: 0.09 sec
# # of episode: 9360, avg score: 9.7, duration: 0.08 sec
# # of episode: 9380, avg score: 9.3, duration: 0.08 sec
# # of episode: 9400, avg score: 9.0, duration: 0.08 sec
# # of episode: 9420, avg score: 9.2, duration: 0.07 sec
# # of episode: 9440, avg score: 9.5, duration: 0.06 sec
# # of episode: 9460, avg score: 9.2, duration: 0.08 sec
# # of episode: 9480, avg score: 9.6, duration: 0.08 sec
# # of episode: 9500, avg score: 9.3, duration: 0.09 sec
# # of episode: 9520, avg score: 9.3, duration: 0.09 sec
# # of episode: 9540, avg score: 9.6, duration: 0.08 sec
# # of episode: 9560, avg score: 9.4, duration: 0.08 sec
# # of episode: 9580, avg score: 9.3, duration: 0.09 sec
# # of episode: 9600, avg score: 9.1, duration: 0.09 sec
# # of episode: 9620, avg score: 9.3, duration: 0.09 sec
# # of episode: 9640, avg score: 9.2, duration: 0.09 sec
# # of episode: 9660, avg score: 9.1, duration: 0.09 sec
# # of episode: 9680, avg score: 9.4, duration: 0.06 sec
# # of episode: 9700, avg score: 9.5, duration: 0.08 sec
# # of episode: 9720, avg score: 9.2, duration: 0.09 sec
# # of episode: 9740, avg score: 9.2, duration: 0.09 sec
# # of episode: 9760, avg score: 9.3, duration: 0.09 sec
# # of episode: 9780, avg score: 9.3, duration: 0.08 sec
# # of episode: 9800, avg score: 9.3, duration: 0.08 sec
# # of episode: 9820, avg score: 9.2, duration: 0.09 sec
# # of episode: 9840, avg score: 9.5, duration: 0.08 sec
# # of episode: 9860, avg score: 9.3, duration: 0.09 sec
# # of episode: 9880, avg score: 9.4, duration: 0.10 sec
# # of episode: 9900, avg score: 9.3, duration: 0.08 sec
# # of episode: 9920, avg score: 9.3, duration: 0.11 sec
# # of episode: 9940, avg score: 9.2, duration: 0.09 sec
# # of episode: 9960, avg score: 9.2, duration: 0.08 sec
# # of episode: 9980, avg score: 9.8, duration: 0.08 sec
