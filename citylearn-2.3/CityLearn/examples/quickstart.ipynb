# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligent-environments-lab/CityLearn/blob/master/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QuickStart
#
# Install the latest CityLearn version from PyPi with the :code:`pip` command:

# %%
# !pip install CityLearn

# %% [markdown]
# ## CityLearn Control Agents

# %% [markdown]
# ### No Control (Baseline)
#
# Run the following to simulate an environment where the storage systems and heat pumps are not controlled (baseline). The storage actions prescribed will be 0.0 and the heat pump will have no action, i.e. `None`, causing it to deliver the ideal load in the building time series files:

# %%
from citylearn.agents.base import BaselineAgent as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\gymnasium\envs\registration.py:604: UserWarning: WARN: plugin: shimmy.registration:register_gymnasium_envs raised Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\gymnasium\envs\registration.py", line 602, in load_plugin_envs
#     fn()
#   File "c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\shimmy\registration.py", line 263, in register_gymnasium_envs
#     _register_atari_envs()
#   File "c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\shimmy\registration.py", line 168, in _register_atari_envs
#     import ale_py
#   File "c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\ale_py\__init__.py", line 55, in <module>
#     register_v0_v4_envs()
#   File "c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\ale_py\registration.py", line 159, in register_v0_v4_envs
#     gymnasium.register(
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: partially initialized module 'gymnasium' has no attribute 'register' (most likely due to a circular import)
#
#   logger.warn(f"plugin: {plugin.value} raised {traceback.format_exc()}")
# Couldn't import dot_parser, loading of dot files will not be possible.
# c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.019       0.018
# carbon_emissions_total                              1.000       1.000
# cost_total                                          1.000       1.000
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       1.657       0.045
# discomfort_cold_delta_maximum                       4.878       1.793
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.369       0.000
# discomfort_hot_delta_average                        0.053       0.577
# discomfort_hot_delta_maximum                        5.006       6.441
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.008       0.041
# discomfort_proportion                               0.377       0.041
# electricity_consumption_total                       1.000       1.000
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.333       0.643
# power_outage_normalized_unserved_energy_total       0.723       0.692
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.000       1.000
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.000
# annual_normalized_unserved_energy_total             0.018     0.018
# carbon_emissions_total                              1.000     1.000
# cost_total                                          1.000     1.000
# daily_one_minus_load_factor_average                   NaN     1.000
# daily_peak_average                                    NaN     1.000
# discomfort_cold_delta_average                       0.675     0.793
# discomfort_cold_delta_maximum                       3.642     3.438
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.095     0.155
# discomfort_hot_delta_average                        0.081     0.237
# discomfort_hot_delta_maximum                        3.734     5.060
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.018
# discomfort_proportion                               0.098     0.172
# electricity_consumption_total                       1.000     1.000
# monthly_one_minus_load_factor_average                 NaN     1.000
# one_minus_thermal_resilience_proportion             0.133     0.370
# power_outage_normalized_unserved_energy_total       0.637     0.684
# ramping_average                                       NaN     1.000
# zero_net_energy                                     1.000     1.000

# %% [markdown]
# ### Centralized RBC
# Run the following to simulate an environment controlled by centralized RBC agent for a single episode:

# %%
from citylearn.agents.rbc import BasicRBC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.017       0.016
# carbon_emissions_total                              1.998       1.936
# cost_total                                          1.931       1.878
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       9.825       3.493
# discomfort_cold_delta_maximum                      13.774       9.875
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.975       0.899
# discomfort_hot_delta_average                        0.005       0.022
# discomfort_hot_delta_maximum                        1.456       4.526
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.000       0.007
# discomfort_proportion                               0.975       0.907
# electricity_consumption_total                       1.995       1.963
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.667       0.500
# power_outage_normalized_unserved_energy_total       0.781       0.759
# ramping_average                                       NaN         NaN
# zero_net_energy                                     2.059       1.994
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.179
# annual_normalized_unserved_energy_total             0.016     0.016
# carbon_emissions_total                              1.740     1.891
# cost_total                                          1.713     1.841
# daily_one_minus_load_factor_average                   NaN     0.720
# daily_peak_average                                    NaN     1.352
# discomfort_cold_delta_average                       3.189     5.502
# discomfort_cold_delta_maximum                       5.514     9.721
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.953     0.942
# discomfort_hot_delta_average                        0.010     0.012
# discomfort_hot_delta_maximum                        3.230     3.071
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.004
# discomfort_proportion                               0.957     0.946
# electricity_consumption_total                       1.755     1.904
# monthly_one_minus_load_factor_average                 NaN     0.863
# one_minus_thermal_resilience_proportion             0.267     0.478
# power_outage_normalized_unserved_energy_total       0.711     0.750
# ramping_average                                       NaN     0.959
# zero_net_energy                                     1.773     1.942

# %% [markdown]
# ### Decentralized-Independent SAC
#
# Run the following to simulate an environment controlled by decentralized-independent SAC agents for 1 training episode:

# %%
from citylearn.agents.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\citylearn\agents\sac.py:117: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ..\torch\csrc\tensor\python_tensor.cpp:80.)
#   o = tensor(o).to(self.device)
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.013       0.013
# carbon_emissions_total                              0.943       0.964
# cost_total                                          0.906       0.926
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       1.911       0.931
# discomfort_cold_delta_maximum                       6.404       4.547
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.446       0.319
# discomfort_hot_delta_average                        0.240       0.536
# discomfort_hot_delta_maximum                        4.605       6.129
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.045       0.149
# discomfort_proportion                               0.491       0.468
# electricity_consumption_total                       0.953       0.982
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.500
# power_outage_normalized_unserved_energy_total       0.627       0.648
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.969       0.985
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.949
# annual_normalized_unserved_energy_total             0.012     0.013
# carbon_emissions_total                              0.958     0.955
# cost_total                                          0.927     0.920
# daily_one_minus_load_factor_average                   NaN     0.941
# daily_peak_average                                    NaN     0.931
# discomfort_cold_delta_average                       0.886     1.243
# discomfort_cold_delta_maximum                       3.030     4.660
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.246     0.337
# discomfort_hot_delta_average                        0.294     0.357
# discomfort_hot_delta_maximum                        3.940     4.891
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.028     0.074
# discomfort_proportion                               0.275     0.411
# electricity_consumption_total                       0.973     0.969
# monthly_one_minus_load_factor_average                 NaN     0.994
# one_minus_thermal_resilience_proportion             0.133     0.456
# power_outage_normalized_unserved_energy_total       0.597     0.624
# ramping_average                                       NaN     0.882
# zero_net_energy                                     0.974     0.976

# %% [markdown]
# ### Decentralized-Cooperative MARLISA
#
# Run the following to simulate an environment controlled by decentralized-cooperative MARLISA agents for 1 training episodes:

# %%
from citylearn.agents.marlisa import MARLISA as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.013       0.013
# carbon_emissions_total                              0.940       0.959
# cost_total                                          0.903       0.921
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       1.904       0.893
# discomfort_cold_delta_maximum                       6.399       4.475
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.447       0.310
# discomfort_hot_delta_average                        0.243       0.557
# discomfort_hot_delta_maximum                        4.645       6.207
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.045       0.153
# discomfort_proportion                               0.492       0.463
# electricity_consumption_total                       0.950       0.977
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.500
# power_outage_normalized_unserved_energy_total       0.628       0.645
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.965       0.979
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.947
# annual_normalized_unserved_energy_total             0.012     0.013
# carbon_emissions_total                              0.940     0.947
# cost_total                                          0.908     0.911
# daily_one_minus_load_factor_average                   NaN     0.945
# daily_peak_average                                    NaN     0.927
# discomfort_cold_delta_average                       0.860     1.219
# discomfort_cold_delta_maximum                       3.000     4.625
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.233     0.330
# discomfort_hot_delta_average                        0.303     0.368
# discomfort_hot_delta_maximum                        3.947     4.933
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.030     0.076
# discomfort_proportion                               0.263     0.406
# electricity_consumption_total                       0.955     0.960
# monthly_one_minus_load_factor_average                 NaN     0.996
# one_minus_thermal_resilience_proportion             0.133     0.456
# power_outage_normalized_unserved_energy_total       0.594     0.622
# ramping_average                                       NaN     0.883
# zero_net_energy                                     0.955     0.966

# %% [markdown]
# ## Other Standard Reinforcement Learning Libraries

# %% [markdown]
# ### Stable Baselines3 Reinforcement Learning Algorithms
#
# Install the latest version of Stable Baselines3:

# %%
# !pip install "stable-baselines3<=2.2.1"

# %% [markdown]
# Before the environment is ready for use in Stable Baselines3, it needs to be wrapped. Firstly, wrap the environment using the `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# Next, we wrap with the `StableBaselines3Wrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.StableBaselines3Wrapper)) that ensures observations, actions and rewards are served in manner that is compatible with Stable Baselines3 interface.
#
# > ⚠️ **NOTE**: `central_agent` in the `env` must be `True` when using Stable Baselines3  as it does not support multi-agents.

# %%
from stable_baselines3.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)
model = Agent('MlpPolicy', env)

# train
episodes = 2
model.learn(total_timesteps=env.unwrapped.time_steps*episodes)

# test
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions, _ = model.predict(observations, deterministic=True)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.011
# carbon_emissions_total                              0.386       0.371
# cost_total                                          0.365       0.346
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       0.000       0.004
# discomfort_cold_delta_maximum                       0.124       0.581
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.000       0.000
# discomfort_hot_delta_average                        9.454       7.004
# discomfort_hot_delta_maximum                       16.701      14.651
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.982       0.978
# discomfort_proportion                               0.982       0.978
# electricity_consumption_total                       0.389       0.378
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             1.000       1.000
# power_outage_normalized_unserved_energy_total       0.572       0.507
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.272       0.356
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.838
# annual_normalized_unserved_energy_total             0.011     0.012
# carbon_emissions_total                              0.555     0.437
# cost_total                                          0.528     0.413
# daily_one_minus_load_factor_average                   NaN     1.288
# daily_peak_average                                    NaN     0.683
# discomfort_cold_delta_average                       0.001     0.002
# discomfort_cold_delta_maximum                       0.394     0.366
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.000     0.000
# discomfort_hot_delta_average                        7.529     7.995
# discomfort_hot_delta_maximum                       12.952    14.768
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.978     0.979
# discomfort_proportion                               0.978     0.979
# electricity_consumption_total                       0.571     0.446
# monthly_one_minus_load_factor_average                 NaN     1.126
# one_minus_thermal_resilience_proportion             1.000     1.000
# power_outage_normalized_unserved_energy_total       0.442     0.507
# ramping_average                                       NaN     0.912
# zero_net_energy                                     0.466     0.365

# %% [markdown]
# ### RLlib
#
# Install the latest version of RLlib:

# %%
# !pip install "ray[rllib]<=2.10.0"

# %% [markdown]
# We advise that you include the `ClippedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.ClippedObservationWrapper)) wrapper when working with RLlib so that observations are always clipped within the observation space before sending to the agent if not, out-of-bound observations will raise a `ValueError` and terminate the training.
#
# We also wrap the environment with `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# RLlib supports both [single-agent and multi-agent algorithms](https://docs.ray.io/en/latest/rllib/rllib-algorithms.html). See below for an example for either case.

# %% [markdown]
# ####  Single Agent
#
# The single-agent interface for RLlib is the `RLlibSingleAgentWrapper` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibSingleAgentWrapper
from ray.rllib.algorithms.sac import SACConfig as Config

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibSingleAgentWrapper, env_config=env_config)
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibSingleAgentWrapper(env_config)
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions = model.compute_single_action(observations, explore=False)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2025-05-20 12:47:38,721	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# 2025-05-20 12:47:40,195	WARNING env.py:162 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2025-05-20 12:47:40,347	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.016
# carbon_emissions_total                              1.626       1.598
# cost_total                                          1.567       1.548
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       7.820       2.915
# discomfort_cold_delta_maximum                      12.422       8.403
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.968       0.741
# discomfort_hot_delta_average                        0.011       0.088
# discomfort_hot_delta_maximum                        2.287       5.453
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.001       0.017
# discomfort_proportion                               0.969       0.757
# electricity_consumption_total                       1.637       1.626
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.643
# power_outage_normalized_unserved_energy_total       0.781       0.796
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.682       1.642
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.062
# annual_normalized_unserved_energy_total             0.014     0.015
# carbon_emissions_total                              1.459     1.561
# cost_total                                          1.428     1.514
# daily_one_minus_load_factor_average                   NaN     0.741
# daily_peak_average                                    NaN     1.165
# discomfort_cold_delta_average                       2.591     4.442
# discomfort_cold_delta_maximum                       5.332     8.719
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.769     0.826
# discomfort_hot_delta_average                        0.013     0.037
# discomfort_hot_delta_maximum                        3.476     3.739
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.007
# discomfort_proportion                               0.772     0.833
# electricity_consumption_total                       1.479     1.581
# monthly_one_minus_load_factor_average                 NaN     0.891
# one_minus_thermal_resilience_proportion             0.267     0.548
# power_outage_normalized_unserved_energy_total       0.708     0.762
# ramping_average                                       NaN     0.885
# zero_net_energy                                     1.488     1.604

# %% [markdown]
# #### Multi-agent
#
# The multi-agent interface for RLlib is the `RLlibMultiAgentEnv` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibMultiAgentEnv
from ray.rllib.algorithms.sac import SACConfig as Config
from ray.rllib.policy.policy import PolicySpec

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibMultiAgentEnv, env_config=env_config)
    .multi_agent(
        policies={a: PolicySpec() for a in RLlibMultiAgentEnv(env_config)._agent_ids},
        policy_mapping_fn=lambda agent_id, episode, worker, **kwargs: agent_id,
    )
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibMultiAgentEnv(env_config)
observations, _ = env.reset()

while not env.terminated:
    actions = {p: model.compute_single_action(o, policy_id=p, explore=False) for p, o in observations.items()}
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2025-05-20 12:47:59,831	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.016
# carbon_emissions_total                              1.630       1.600
# cost_total                                          1.570       1.549
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       7.842       2.931
# discomfort_cold_delta_maximum                      12.443       8.428
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.969       0.744
# discomfort_hot_delta_average                        0.011       0.087
# discomfort_hot_delta_maximum                        2.273       5.421
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.001       0.017
# discomfort_proportion                               0.971       0.761
# electricity_consumption_total                       1.641       1.627
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.643
# power_outage_normalized_unserved_energy_total       0.781       0.796
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.685       1.644
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.063
# annual_normalized_unserved_energy_total             0.014     0.015
# carbon_emissions_total                              1.459     1.563
# cost_total                                          1.428     1.516
# daily_one_minus_load_factor_average                   NaN     0.740
# daily_peak_average                                    NaN     1.166
# discomfort_cold_delta_average                       2.590     4.455
# discomfort_cold_delta_maximum                       5.334     8.735
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.767     0.827
# discomfort_hot_delta_average                        0.013     0.037
# discomfort_hot_delta_maximum                        3.476     3.724
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.007
# discomfort_proportion                               0.770     0.834
# electricity_consumption_total                       1.480     1.583
# monthly_one_minus_load_factor_average                 NaN     0.891
# one_minus_thermal_resilience_proportion             0.267     0.548
# power_outage_normalized_unserved_energy_total       0.708     0.762
# ramping_average                                       NaN     0.885
# zero_net_energy                                     1.489     1.606

# %% [markdown]
# ## Neighborhood Dataset Generation
#
# Aside the provided datasets that come with the CityLearn installation, custom single-family residential datasets can be generated in CityLearn by taking advantage of the [End-Use Load Profiles for the U.S. Building Stock dataset](https://www.nrel.gov/buildings/end-use-load-profiles.html). The [citylearn.end_use_load_profiles.neighborhood.Neighborhood](https://www.citylearn.net/api/citylearn.end_use_load_profiles.neighborhood.html#citylearn.end_use_load_profiles.neighborhood.Neighborhood) class makes this possible.
#
# To learn more about the methodology used in this feature, refer to the [CityLearn v2 paper](https://doi.org/10.1080/19401493.2024.2418813).
#
# Note that to make use of this feature, [EnergyPlus 9.6.0](https://github.com/NREL/EnergyPlus/releases/tag/v9.6.0) must be installed. Other EnergyPlus versions are not yet supported.
#
# An example of a generating a dataset and using it in simulation is:

# %%
from citylearn.agents.rbc import BasicRBC as Agent
from citylearn.citylearn import CityLearnEnv
from citylearn.end_use_load_profiles.neighborhood import Neighborhood, SampleMethod

# path to version EnergyPlus 9.6.0 IDD
idd_filepath = '/Applications/EnergyPlus-9-6-0/PreProcess/IDFVersionUpdater/V9-6-0-Energy+.idd'

# build a neighborhood with n buildings through random sampling of single-family residential buildings in EULP dataset.
# Sampling population is filtered to include specific county and building vintage.
# train their LSTM thermal dynamics models and generate a CityLearn schema for the two buildings
neighborhood = Neighborhood()
n = 2
neighborhood_build = neighborhood.build(
    idd_filepath=idd_filepath,
    delete_energyplus_simulation_output=True,
    sample_buildings_kwargs=dict(
        sample_method=SampleMethod.RANDOM,
        sample_count=n,
        filters={
            'in.resstock_county_id': ['TX, Travis County'],
            'in.vintage': ['2000s']
        },
    ),
)

# simulate neighborhood in CityLearn
env = CityLearnEnv(neighborhood_build.schema_filepath, central_agent=True)
model = Agent(env)
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 from citylearn.agents.rbc import BasicRBC as Agent
#       2 from citylearn.citylearn import CityLearnEnv
# ----> 3 from citylearn.end_use_load_profiles.neighborhood import Neighborhood, SampleMethod
#       5 # path to version EnergyPlus 9.6.0 IDD
#       6 idd_filepath = '/Applications/EnergyPlus-9-6-0/PreProcess/IDFVersionUpdater/V9-6-0-Energy+.idd'
#
# File c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\citylearn\end_use_load_profiles\neighborhood.py:10
#       8 from typing import Any, Callable, List, Mapping, Tuple, Union
#       9 from doe_xstock.data import VersionDatasetType
# ---> 10 from doe_xstock.end_use_load_profiles import EndUseLoadProfiles
#      11 from doe_xstock.simulate import EndUseLoadProfilesEnergyPlusSimulator, OpenStudioModelEditor
#      12 import numpy as np
#
# File c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\doe_xstock\end_use_load_profiles.py:19
#       5 from pandas import DataFrame
#       6 from doe_xstock.data import (
#       7     DataDictionary,
#       8     EnumerationDictionary,
#    (...)     17     Weather
#      18 )
# ---> 19 from doe_xstock.simulate import EndUseLoadProfilesEnergyPlusSimulator
#      21 class EndUseLoadProfilesMetadata:
#      22     def __init__(self, version: Version):
#
# File c:\Users\User\anaconda3\envs\citylearn\Lib\site-packages\doe_xstock\simulate.py:10
#       8 from eppy.modeleditor import IDDNotSetError, IDF
#       9 from eppy.runner.run_functions import EnergyPlusRunError, runIDFs
# ---> 10 from openstudio import energyplus, isomodel, osversion, openstudiomodelcore
#      11 import pandas as pd
#      12 from doe_xstock.data import Data, Version, VersionDatasetType
#
# ModuleNotFoundError: No module named 'openstudio'
